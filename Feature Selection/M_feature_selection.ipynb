# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt
color_pal = [x['color'] for x in plt.rcParams['axes.prop_cycle']]

# %%
dataframe.head()
# Out:
#     M1   M2   M3   M4   M5   M6   M7   M8   M9  isFraud
# 0    T    T    T   M2    F    T  NaN  NaN  NaN        0
# 1  NaN  NaN  NaN   M0    T    T  NaN  NaN  NaN        0
# 2    T    T    T   M0    F    F    F    F    F        0
# 3  NaN  NaN  NaN   M0    T    F  NaN  NaN  NaN        0
# 4  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN  NaN        0

# %%
m_cols = [c for c in train_transaction if c[0] == 'M']

# %%
(dataframe[m_cols] == 'T').sum().plot(kind='bar',
                                              title='Count of T by M column',
                                              figsize=(15, 2),
                                              color=color_pal[3])
plt.show()
(dataframe[m_cols] == 'F').sum().plot(kind='bar',
                                              title='Count of F by M column',
                                              figsize=(15, 2),
                                              color=color_pal[4])
plt.show()
(dataframe[m_cols].isna()).sum().plot(kind='bar',
                                              title='Count of NaN by M column',
                                              figsize=(15, 2),
                                              color=color_pal[0])
plt.show()

# %% [markdown]
# M1 is missing, because there is no False value, therefore it is bias
#
# Remove M1

# %%
# Looking at M4 column since it is different than the others
dataframe.groupby('M4')['M4'] \
    .count() \
    .plot(kind='bar',
          title='Count of values for M4',
          figsize=(15, 3))
plt.show()

# %% [markdown]
# Filter Method

# %% [markdown]
# The correlation coefficient has values between -1 to 1
#
# — A value closer to 0 implies weaker correlation (exact 0 implying no correlation)
#
# — A value closer to 1 implies stronger positive correlation
#
# — A value closer to -1 implies stronger negative correlation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Using Pearson Correlation
Ms = ['M'+str(x) for x in range(1,10)]
mp = {'F':0,'T':1,'M0':0,'M1':1,'M2':2}
for c in Ms: dataframe[c] = dataframe[c].map(mp)

cols = ['isFraud'] + Ms
plt.figure(figsize=(15,15))
sns.heatmap(dataframe[cols].corr(), cmap='RdBu_r', annot=True, center=0.0)
plt.title('M1-M9')
plt.show()
